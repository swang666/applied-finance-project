# %%
import pickle

# %%
with open('tf-idf.model', "rb") as model_file:
    model = pickle.load(model_file)
# Out:
# c:\users\sumen\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.21.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# c:\users\sumen\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.21.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
import pandas as pd
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b8591eb44077> in <module>
# ----> 1 model.shape
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'shape'

# %%
df_idf = pd.DataFrame(model, index=model.get_feature_names(),columns=["idf"])

# %%
model
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True,
#                 stop_words={'a', 'about', 'above', 'after', 'again', 'against',
#                             'ain', 'all', 'am', 'an', 'and', 'any', 'are',
#                             'aren', "aren't", 'as', 'at', 'be', 'because',
#                             'been', 'before', 'being', 'below', 'between',
#                             'both', 'but', 'by', 'can', 'couldn', "couldn't", ...},
#                 strip_accents=None, sublinear_tf=False,
#                 token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=<function word_tokenize at 0x000002B04D8B6E18>,
#                 use_idf=True, vocabulary=None)

# %%
topic0 = ['investment property distribution interest agreement']

# %%
first_vector_tfidfvectorizer=model.transform(topic0[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9f21a96795bf> in <module>
# ----> 1 first_vector_tfidfvectorizer=model.transform(topic0[0])
#
# c:\users\sumen\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_extraction\text.py in transform(self, raw_documents, copy)
#    1678         check_is_fitted(self, '_tfidf', 'The tfidf vector is not fitted')
#    1679
# -> 1680         X = super().transform(raw_documents)
#    1681         return self._tfidf.transform(X, copy=False)
#    1682
#
# c:\users\sumen\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_extraction\text.py in transform(self, raw_documents)
#    1101         if isinstance(raw_documents, str):
#    1102             raise ValueError(
# -> 1103                 "Iterable over raw text documents expected, "
# ...

# %%
df = pd.DataFrame(first_vector_tfidfvectorizer.T.todense(), index=model.get_feature_names(), columns=["tfidf"])
df.sort_values(by=["tfidf"],ascending=False)
# Out:
#                                     tfidf
# distribution                     0.535867
# property                         0.469326
# investment                       0.418359
# agreement                        0.407904
# interest                         0.388805
# '                                0.000000
# program.dividends                0.000000
# program.discussion               0.000000
# program.distribution             0.000000
# program.distributionon           0.000000
# program.distributions            0.000000
# program.dividend                 0.000000
# program.dividends/distributions  0.000000
# program.director                 0.000000
# program.dividendsa               0.000000
# program.dividendsfor             0.000000
# program.dividendsin              0.000000
# program.dividendson              0.000000
# program.dividendsour             0.000000
# program.dividendsthe             0.000000
# program.discontinued             0.000000
# ...

# %%
first_vector_tfidfvectorizer.toarray()
# Out:
# array([[0.4472136, 0.4472136, 0.4472136, 0.4472136, 0.4472136]])

# %%
model
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True,
#                 stop_words={'a', 'about', 'above', 'after', 'again', 'against',
#                             'ain', 'all', 'am', 'an', 'and', 'any', 'are',
#                             'aren', "aren't", 'as', 'at', 'be', 'because',
#                             'been', 'before', 'being', 'below', 'between',
#                             'both', 'but', 'by', 'can', 'couldn', "couldn't", ...},
#                 strip_accents=None, sublinear_tf=False,
#                 token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=<function word_tokenize at 0x000001E327057E18>,
#                 use_idf=True, vocabulary=None)
